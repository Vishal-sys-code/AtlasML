# %%
# !pip install gensim

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
# !pip install wget

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("leadbest/googlenewsvectorsnegative300")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/googlenewsvectorsnegative300

# %%
model = KeyedVectors.load_word2vec_format('/root/.cache/kagglehub/datasets/leadbest/googlenewsvectorsnegative300/versions/2/GoogleNews-vectors-negative300.bin.gz', binary = True)

# %%
model['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
model['cricket'].shape
# Out:
# (300,)

# %%
model['dhoni'].shape
# Out:
# (300,)

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.most_similar('dhoni')
# Out:
# [('sehwag', 0.5971179604530334),
#  ('sachin', 0.5636177659034729),
#  ('ponting', 0.5531018376350403),
#  ('dravid', 0.5510292053222656),
#  ('Yuvraj_Singh_Suresh_Raina', 0.5448464155197144),
#  ('Fazil_Marija', 0.5439736843109131),
#  ('irfan', 0.5431955456733704),
#  ('odi', 0.5412436723709106),
#  ('Kavaratti', 0.5402672290802002),
#  ('INS_Godavari', 0.538774311542511)]

# %%
model.similarity('cricket', 'dhoni')
# Out:
# 0.3664089

# %%
model.similarity('cricket', 'messi')
# Out:
# 0.21781033

# %%
model.doesnt_match(['man', 'woman', 'monkey'])
# Out:
# 'monkey'

# %%
model.doesnt_match(['man', 'woman', 'cricket'])
# Out:
# 'cricket'

# %%
model.doesnt_match(['man', 'messi', 'dhoni'])
# Out:
# 'man'

# %%
model.doesnt_match(['intelligent', 'woman', 'machines'])
# Out:
# 'woman'

# %%
vec = model['king'] - model['man'] - model['woman']
model.most_similar([vec])
# Out:
# [('king', 0.4048772156238556),
#  ('kings', 0.30023127794265747),
#  ('Pansy_Ho_Chiu', 0.27302688360214233),
#  ('Hassle_Free_Lead', 0.26562565565109253),
#  ('du_Grand_Controle', 0.2622641623020172),
#  ('conf_C####_TORONTO', 0.2607021629810333),
#  ('Nickerson_Zwaan', 0.25404006242752075),
#  ('José_Luis_Villegas_jvillegas@sacbee.com', 0.24456088244915009),
#  ('Cadec_Mobius_TTS', 0.2437450885772705),
#  ('Bahrain_Sheik_Hamad', 0.23861853778362274)]

# %%
vec = model['INR'] - model ['India'] + model['England']
model.most_similar([vec])
# Out:
# [('INR', 0.6442341208457947),
#  ('GBP', 0.5040826797485352),
#  ('£_##.###m', 0.4540838301181793),
#  ('England', 0.44649264216423035),
#  ('£', 0.43340998888015747),
#  ('Â_£', 0.4307197630405426),
#  ('stg###', 0.4299262464046478),
#  ('£_#.##m', 0.42561301589012146),
#  ('Pounds_Sterling', 0.42512619495391846),
#  ('GBP##', 0.42464491724967957)]

# %%
vec = model['AI'] - model ['Google'] + model['Facebook']
model.most_similar([vec])
# Out:
# [('AI', 0.6794990301132202),
#  ('facebook', 0.4780747890472412),
#  ('Facebook', 0.4322681725025177),
#  ('FaceBook', 0.40951278805732727),
#  ('twitter', 0.4055844843387604),
#  ('Career_Mode', 0.39597684144973755),
#  ('Steven_Spielberg_Artificial_Intelligence', 0.3951604664325714),
#  ('multiplayer', 0.389379620552063),
#  ('DOA4', 0.38684186339378357),
#  ('Counterstrike', 0.38267818093299866)]
